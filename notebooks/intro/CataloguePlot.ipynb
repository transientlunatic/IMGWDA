# %%
data_gw1 = {
  "data": {
    "GW150914": {
      "E_rad": {
        "best": 3.1, 
        "err": [
          -0.4, 
          0.4
        ]
      }, 
      "L_peak": {
        "best": 3.6, 
        "err": [
          -0.4, 
          0.4
        ]
      }, 
      "a_final": {
        "best": 0.69, 
        "err": [
          -0.04, 
          0.05
        ]
      }, 
      "chi_eff": {
        "best": -0.01, 
        "err": [
          -0.13, 
          0.12
        ]
      }, 
      "distance": {
        "best": 430.0, 
        "err": [
          -170.0, 
          150.0
        ]
      }, 
      "far_cwb": {
        "best": 0.000163, 
        "err": "upperbound"
      }, 
      "far_gstlal": {
        "best": 1e-07, 
        "err": "upperbound"
      }, 
      "far_pycbc": {
        "best": 1.5300000000000003e-05, 
        "err": "upperbound"
      }, 
      "mass1": {
        "best": 35.6, 
        "err": [
          -3.0, 
          4.8
        ]
      }, 
      "mass2": {
        "best": 30.6, 
        "err": [
          -4.4, 
          3.0
        ]
      }, 
      "mchirp": {
        "best": 28.6, 
        "err": [
          -1.5, 
          1.6
        ]
      }, 
      "mfinal": {
        "best": 63.1, 
        "err": [
          -3.0, 
          3.3
        ]
      }, 
      "redshift": {
        "best": 0.09, 
        "err": [
          -0.03, 
          0.03
        ]
      }, 
      "sky_size": {
        "best": 179.0
      }, 
      "snr_cwb": {
        "best": 25.2
      }, 
      "snr_gstlal": {
        "best": 24.4
      }, 
      "snr_pycbc": {
        "best": 23.6
      }, 
      "tc": {
        "best": 1126259462.4
      }, 
      "utctime": {
        "best": "09:50:45.4"
      }
    }, 
    "GW151012": {
      "E_rad": {
        "best": 1.5, 
        "err": [
          -0.5, 
          0.5
        ]
      }, 
      "L_peak": {
        "best": 3.2, 
        "err": [
          -1.7, 
          0.8
        ]
      }, 
      "a_final": {
        "best": 0.67, 
        "err": [
          -0.11, 
          0.13
        ]
      }, 
      "chi_eff": {
        "best": 0.04, 
        "err": [
          -0.19, 
          0.28
        ]
      }, 
      "distance": {
        "best": 1060.0, 
        "err": [
          -480.0, 
          540.0
        ]
      }, 
      "far_cwb": {
        "best": "NA"
      }, 
      "far_gstlal": {
        "best": 0.00792
      }, 
      "far_pycbc": {
        "best": 0.17
      }, 
      "mass1": {
        "best": 23.3, 
        "err": [
          -5.5, 
          14.0
        ]
      }, 
      "mass2": {
        "best": 13.6, 
        "err": [
          -4.8, 
          4.1
        ]
      }, 
      "mchirp": {
        "best": 15.2, 
        "err": [
          -1.1, 
          2.0
        ]
      }, 
      "mfinal": {
        "best": 35.7, 
        "err": [
          -3.8, 
          9.9
        ]
      }, 
      "redshift": {
        "best": 0.21, 
        "err": [
          -0.09, 
          0.09
        ]
      }, 
      "sky_size": {
        "best": 1555.0
      }, 
      "snr_cwb": {
        "best": "NA"
      }, 
      "snr_gstlal": {
        "best": 10.0
      }, 
      "snr_pycbc": {
        "best": 9.5
      }, 
      "tc": {
        "best": 1128678900.4
      }, 
      "utctime": {
        "best": "09:54:43.4"
      }
    }, 
    "GW151226": {
      "E_rad": {
        "best": 1.0, 
        "err": [
          -0.09, 
          0.08
        ]
      }, 
      "chi_eff": {
        "best": 0.07, 
        "err": [
          -0.16, 
          0.16
        ]
      }, 
      "distance": {
        "best": 990.0, 
        "err": [
          -380.0, 
          320.0
        ]
      }, 
      "far_cwb": {
        "best": "NA"
      }, 
      "far_gstlal": {
        "best": 1e-07, 
        "err": "upperbound"
      }, 
      "far_pycbc": {
        "best": 0.000145
      }, 
      "mass1": {
        "best": 35.2, 
        "err": [
          -6.0, 
          8.3
        ]
      }, 
      "mass2": {
        "best": 23.8, 
        "err": [
          -5.1, 
          5.2
        ]
      }, 
      "mchirp": {
        "best": 25.0, 
        "err": [
          -1.6, 
          2.1
        ]
      }, 
      "mfinal": {
        "best": 56.4, 
        "err": [
          -3.7, 
          5.2
        ]
      }, 
      "redshift": {
        "best": 0.2, 
        "err": [
          -0.07, 
          0.05
        ]
      }, 
      "sky_size": {
        "best": 340.0
      }, 
      "snr_cwb": {
        "best": "NA"
      }, 
      "snr_gstlal": {
        "best": 12.4
      }, 
      "snr_pycbc": {
        "best": 12.2
      }, 
      "tc": {
        "best": 1186302519.8
      }, 
      "utctime": {
        "best": "08:28:21.8"
      }
    }, 
    "GW170814": {
      "E_rad": {
        "best": 2.7, 
        "err": [
          -0.3, 
          0.4
        ]
      }, 
      "L_peak": {
        "best": 3.7, 
        "err": [
          -0.5, 
          0.4
        ]
      }, 
      "a_final": {
        "best": 0.72, 
        "err": [
          -0.05, 
          0.07
        ]
      }, 
      "chi_eff": {
        "best": 0.07, 
        "err": [
          -0.11, 
          0.12
        ]
      }, 
      "distance": {
        "best": 580.0, 
        "err": [
          -210.0, 
          160.0
        ]
      }, 
      "far_cwb": {
        "best": 0.00020800000000000001, 
        "err": "upperbound"
      }, 
      "far_gstlal": {
        "best": 1e-07, 
        "err": "upperbound"
      }, 
      "far_pycbc": {
        "best": 1.25e-05, 
        "err": "upperbound"
      }, 
      "mass1": {
        "best": 30.7, 
        "err": [
          -3.0, 
          5.7
        ]
      }, 
      "mass2": {
        "best": 25.3, 
        "err": [
          -4.1, 
          2.9
        ]
      }, 
      "mchirp": {
        "best": 24.2, 
        "err": [
          -1.1, 
          1.4
        ]
      }, 
      "mfinal": {
        "best": 53.4, 
        "err": [
          -2.4, 
          3.2
        ]
      }, 
      "redshift": {
        "best": 0.12, 
        "err": [
          -0.04, 
          0.03
        ]
      }, 
      "sky_size": {
        "best": 87.0
      }, 
      "snr_cwb": {
        "best": 17.2
      }, 
      "snr_gstlal": {
        "best": 15.9
      }, 
      "snr_pycbc": {
        "best": 16.3
      }, 
      "tc": {
        "best": 1186741861.5
      }, 
      "utctime": {
        "best": "10:30:43.5"
      }
    }, 
    "GW170817": {
      "E_rad": {
        "best": 0.04, 
        "err": "lowerbound"
      }, 
      "L_peak": {
        "best": 0.1, 
        "err": "lowerbound"
      }, 
      "a_final": {
        "best": 0.89, 
        "err": "upperbound"
      }, 
      "chi_eff": {
        "best": 0.0, 
        "err": [
          -0.01, 
          0.02
      }, 
      "far_gstlal": {
        "best": 1e-07, 
        "err": "upperbound"
      }, 
      "far_pycbc": {
        "best": 3.29e-05, 
        "err": "upperbound"
      }, 
      "mass1": {
        "best": 39.6, 
        "err": [
          -6.6, 
          10.0
        ]
      }, 
      "mass2": {
        "best": 29.4, 
        "err": [
          -7.1, 
          6.3
        ]
      }, 
      "mchirp": {
        "best": 29.3, 
        "err": [
          -3.2, 
          4.2
        ]
      }, 
      "mfinal": {
        "best": 65.6, 
        "err": [
          -6.6, 
          9.4
        ]
      }, 
      "redshift": {
        "best": 0.34, 
        "err": [
          -0.14, 
          0.13
        ]
      }, 
      "sky_size": {
        "best": 1651.0
      }, 
      "snr_cwb": {
        "best": 10.8
      }, 
      "snr_gstlal": {
        "best": 11.5
      }, 
      "snr_pycbc": {
        "best": 11.1
      }, 
      "tc": {
        "best": 1187529256.5
      }, 
      "utctime": {
        "best": "13:13:58.5"
      }
    }
  }, 
  "parameters": {
    "E_rad": {
      "name_en": "Radiated energy", 
      "priority": 6, 
      "sigfig": 1, 
      "unit_en": "M_sun X c^2"
    }, 
    "L_peak": {
      "name_en": "Peak luminosity", 
      "priority": 6, 
      "sigfig": 1, 
      "unit_en": "10^56 erg s^-1"
    }, 
    "a_final": {
      "name_en": "Final spin", 
      "priority": 3, 
      "sigfig": 2
    }, 
    "chi_eff": {
      "name_en": "Effective inspiral spin", 
      "priority": 2, 
      "sigfig": 2
    }, 
    "distance": {
      "name_en": "Luminosity distance", 
      "priority": 4, 
      "sigfig": 0, 
      "unit_en": "Mpc"
    }, 
    "far_cwb": {
      "name_en": "FAR cWB", 
      "priority": 6, 
      "sigfig": 2, 
      "unit_en": "yr^-1"
    }, 
    "far_gstlal": {
      "name_en": "FAR gstLAL", 
      "priority": 6, 
      "sigfig": 2, 
      "unit_en": "yr^-1"
    }, 
    "far_pycbc": {
      "name_en": "FAR PyCBC", 
      "priority": 6, 
      "sigfig": 2, 
      "unit_en": "yr^-1"
    }, 
    "mass1": {
      "name_en": "Primary mass", 
      "priority": 1, 
      "sigfig": 1, 
      "unit_en": "M_sun"
    }, 
    "mass2": {
      "name_en": "Secondary mass", 
      "priority": 1, 
      "sigfig": 1, 
      "unit_en": "M_sun"
    }, 
    "mchirp": {
      "name_en": "chirp mass", 
      "priority": 2, 
      "sigfig": 1, 
      "unit_en": "M_sun"
    }, 
    "mfinal": {
      "name_en": "Final mass", 
      "priority": 3, 
      "sigfig": 1, 
      "unit_en": "M_sun"
    }, 
    "redshift": {
      "name_en": "Source redshift", 
      "priority": 6, 
      "sigfig": 2
    }, 
    "sky_size": {
      "name_en": "Sky localization", 
      "priority": 6, 
      "sigfig": 0, 
      "unit_en": "deg^2"
    }, 
    "snr_cwb": {
      "name_en": "Network SNR cWB", 
      "priority": 6, 
      "sigfig": 1
    }, 
    "snr_gstlal": {
      "name_en": "Network SNR gstLAL", 
      "priority": 6, 
      "sigfig": 1
    }, 
    "snr_pycbc": {
      "name_en": "Network SNR PyCBC", 
      "priority": 6, 
      "sigfig": 1
    }, 
    "tc": {
      "name_en": "GPS time (s)", 
      "priority": 5, 
      "sigfig": 1
    }, 
    "utctime": {
      "name_en": "UTCtime", 
      "priority": 6, 
      "sigfig": 0
    }
  }
}

# %%
import pandas as pd

# %%
data_gw1 = pd.read_json("../../data/gwtc1.json").transpose()

# %%
import re

# %%
number = re.match(pattern=pattern, string=str(a))

# %%
number.groups()
# Out:
# ('1', '5')

# %%
a

# %%
def error_parse(x):
    if "best" in x:
        pattern = "([0-9]*)E([+\-0-9])*"
        number = re.match(pattern=pattern, string=str(x['best']))
        if not number == None:
            out = "{}\ee{{{}}}"
            x['best'] = out.format(number.group(1), number.group(2))
                                           
    
    if "err" in x:
        if type(x['err'])== list:
            output = "{}^{{+{}}}_{{{}}}"
            return output.format(x['best'], x['err'][1], x['err'][0])
        elif x['err'] == "lowerbound":
            output = "> {}"
            return output.format(x['best'])
        elif x['err'] == "upperbound":
            output = "< {}"
            return output.format(x['best'])
    else:
        return x['best']

# %%
data_gw1.applymap(error_parse)
# Out:
#                       E_rad             L_peak               a_final  \
# GW150914  3.1^{+0.4}_{-0.4}  3.6^{+0.4}_{-0.4}  0.69^{+0.05}_{-0.04}
# GW151012  1.5^{+0.5}_{-0.5}  3.2^{+0.8}_{-1.7}  0.67^{+0.13}_{-0.11}
# GW151226  1.0^{+0.1}_{-0.2}  3.4^{+0.7}_{-1.7}  0.74^{+0.07}_{-0.05}
# GW170104  2.2^{+0.5}_{-0.5}  3.3^{+0.6}_{-0.9}   0.66^{+0.08}_{-0.1}
# GW170608  0.9^{+0.0}_{-0.1}  3.5^{+0.4}_{-1.3}  0.69^{+0.04}_{-0.04}
# GW170729  4.8^{+1.7}_{-1.7}  4.2^{+0.9}_{-1.5}  0.81^{+0.07}_{-0.13}
# GW170809  2.7^{+0.6}_{-0.6}  3.5^{+0.6}_{-0.9}   0.7^{+0.08}_{-0.09}
# GW170814  2.7^{+0.4}_{-0.3}  3.7^{+0.4}_{-0.5}  0.72^{+0.07}_{-0.05}
# GW170817             > 0.04              > 0.1                < 0.89
# GW170818  2.7^{+0.5}_{-0.5}  3.4^{+0.5}_{-0.7}  0.67^{+0.07}_{-0.08}
# GW170823  3.3^{+0.9}_{-0.8}  3.6^{+0.6}_{-0.9}   0.71^{+0.08}_{-0.1}
#
#                         chi_eff                    distance     far_cwb  \
# ...

# %%
catalogue = pd.DataFrame(data_gw1['data']).transpose()

# %%
catalogue = data_gw1#.transpose()

# %%
catalogue
# Out:
#                                            E_rad  \
# GW150914     {u'err': [-0.4, 0.4], u'best': 3.1}
# GW151012     {u'err': [-0.5, 0.5], u'best': 1.5}
# GW151226     {u'err': [-0.2, 0.1], u'best': 1.0}
# GW170104     {u'err': [-0.5, 0.5], u'best': 2.2}
# GW170608     {u'err': [-0.1, 0.0], u'best': 0.9}
# GW170729     {u'err': [-1.7, 1.7], u'best': 4.8}
# GW170809     {u'err': [-0.6, 0.6], u'best': 2.7}
# GW170814     {u'err': [-0.3, 0.4], u'best': 2.7}
# GW170817  {u'err': u'lowerbound', u'best': 0.04}
# GW170818     {u'err': [-0.5, 0.5], u'best': 2.7}
# GW170823     {u'err': [-0.8, 0.9], u'best': 3.3}
#
#                                          L_peak  \
# GW150914    {u'err': [-0.4, 0.4], u'best': 3.6}
# GW151012    {u'err': [-1.7, 0.8], u'best': 3.2}
# GW151226    {u'err': [-1.7, 0.7], u'best': 3.4}
# GW170104    {u'err': [-0.9, 0.6], u'best': 3.3}
# GW170608    {u'err': [-1.3, 0.4], u'best': 3.5}
# GW170729    {u'err': [-1.5, 0.9], u'best': 4.2}
# ...

# %%
columns = [r"Number", r"$E_{\text rad}$", r"$L_{\text peak}$", r"$a_{\text fin}$",
          r"$\chi_{\text eff}$", r"$D_{\text L}$"
          ]

# %%
catalogue.columns
# Out:
# Index([u'E_rad', u'L_peak', u'a_final', u'chi_eff', u'distance', u'far_cwb',
#        u'far_gstlal', u'far_pycbc', u'mass1', u'mass2', u'mchirp', u'mfinal',
#        u'redshift', u'sky_size', u'snr_cwb', u'snr_gstlal', u'snr_pycbc',
#        u'tc', u'utctime'],
#       dtype='object')

# %%
catalogue
# Out:
#                                            E_rad  \
# GW150914     {u'err': [-0.4, 0.4], u'best': 3.1}
# GW151012     {u'err': [-0.5, 0.5], u'best': 1.5}
# GW151226     {u'err': [-0.2, 0.1], u'best': 1.0}
# GW170104     {u'err': [-0.5, 0.5], u'best': 2.2}
# GW170608     {u'err': [-0.1, 0.0], u'best': 0.9}
# GW170729     {u'err': [-1.7, 1.7], u'best': 4.8}
# GW170809     {u'err': [-0.6, 0.6], u'best': 2.7}
# GW170814     {u'err': [-0.3, 0.4], u'best': 2.7}
# GW170817  {u'err': u'lowerbound', u'best': 0.04}
# GW170818     {u'err': [-0.5, 0.5], u'best': 2.7}
# GW170823     {u'err': [-0.8, 0.9], u'best': 3.3}
#
#                                          L_peak  \
# GW150914    {u'err': [-0.4, 0.4], u'best': 3.6}
# GW151012    {u'err': [-1.7, 0.8], u'best': 3.2}
# GW151226    {u'err': [-1.7, 0.7], u'best': 3.4}
# GW170104    {u'err': [-0.9, 0.6], u'best': 3.3}
# GW170608    {u'err': [-1.3, 0.4], u'best': 3.5}
# GW170729    {u'err': [-1.5, 0.9], u'best': 4.2}
# ...

# %%
a = 1e-5

# %%
str(a)
# Out:
# '1e-05'

# %%
import matplotlib.pyplot as plt

# %%
from matplotlib import gridspec

# %%
columns = [u'L_peak',  u'chi_eff', #u'distance', #u'far_cwb',
        u'mass1', u'mass2', #u'mchirp', u'mfinal', #u'far_gstlal', u'far_pycbc',
       u'redshift', u'sky_size', #u'snr_cwb', u'snr_gstlal', u'snr_pycbc',
       #u'tc', u'utctime']
          ]

# %%
import numpy as np

# %%
import thesis

# %%
fig_dir = "../../figures/"
fig_ext = "pdf"

# %%
data = catalogue[columns][catalogue.index != "GW170817"]

f = plt.figure(figsize=(15,15), dpi=300)

#if not isinstance(additional, pd.DataFrame):
#    # Convert additional to an array
#    additional = pd.DataFrame(additional)

# produce an n x n grid of subplots
gs = gridspec.GridSpec(len(data.columns), len(data.columns),
                       wspace=0.0, hspace=0.0)

prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']

# Make a legend for the additional points
#legend_ax = plt.subplot(gs[1,3])
#legend_ax.axis("off")
#legend_ax.grid(None)
#for i, point in enumerate(additional.iterrows()):
#     legend_ax.scatter(0, i, marker="o", c=point[1]['color'], alpha=0.7)
#     legend_ax.text(0.02, i, point[1]['label'], ha="left", va="center", fontdict=lato)
#legend_ax.set_xlim([-0.05, 0.3])

for i, parameter in enumerate(data.columns):
    for j, j_parameter in enumerate(data.columns):

        if i >= j:
            # Don't produce a plot for combinations above the
            # diagonal.
            continue
        else:
            # Produce a subplot for combinations on or below
            # the diagonal
            ax = plt.subplot(gs[j, i])
            ax.grid(None)

        if i == j:
            pass
        #    # This is the on-diagonal case, which we'll just skip for
        #    # now. Ideally will want to insert a histogram here.
        #    ax.hist(map(lambda x: x['best'], data[parameter]), histtype="step")
        #    ax.yaxis.tick_right()
        #    ax.set_yticks(ax.get_yticks()[1:-1])
        else:

            # Add in the 'additional' points
            #ax.scatter(additional[parameter], additional[j_parameter], marker="o", c=additional['color'], alpha=0.7)


            # Produce a scatter plot of the waveforms for this
            # combination
            #ax.scatter(map(lambda x: x['best'], data[parameter]),
            #           map(lambda x: x['best'], data[j_parameter]),
            #           marker=".")
            
            def return_bounds(x):
                if "err" in x:
                    lims = np.array([0,0])
                    bounds = np.array([0,0])
                    if x["err"][5:] != "bound":
                        bounds =  np.array(x['err']) 
                    elif x["err"] == "upperbound":
                        bounds = np.array([0, 1])
                        lims = np.array([0, 1])
                    elif x["err"] == "lowerbound":
                        lims = np.array([1, 0])
                        bounds = np.array([1, 0])
                    bounds[0] *= -1
                    return bounds, lims
                else:
                    return np.array([0,0]), np.array([0,0]), np.array([0,0])
            
            xerr = np.array(map(return_bounds , data[parameter]))[:,0]
            xlim =  np.array(map(return_bounds , data[parameter]))[:,1]
            yerr = np.array(map(return_bounds, data[j_parameter]))[:,0]
            ylim = np.array(map(return_bounds, data[j_parameter]))[:,1]

            ax.errorbar(x=map(lambda x: x['best'], data[parameter]),
                    y=map(lambda x: x['best'], data[j_parameter]),
                    xerr=xerr.T,
                        color=thesis.colors['blue'],
                    xlolims=xlim[:,0],
                        xuplims=xlim[:,1],
                        lolims=ylim[:,0],
                        uplims=ylim[:,1],
                    yerr=yerr.T,
                        lw=0.5,
                    ls="", marker=".", markersize=1.5)
            
            
        if j == len(data.columns) - 1:
            ax.set_xlabel(parameter.replace("_", " "))
        else:
            ax.set_xticks([])

        if i == 0:
            ax.set_ylabel(j_parameter.replace("_", " "))
        elif not i == j:
            ax.set_yticks([])

#f.tight_layout()

f = thesis.thesisify(f, height=1.5)

f.savefig("{}/intro/catalogue.{}".format(fig_dir, fig_ext))
# Out:
# /home/daniel/.virtualenvs/IGRlaptop21/thesis/lib/python2.7/site-packages/matplotlib/backends/backend_pdf.py:1120: UserWarning: 'SourceCodePro-Regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
#   warnings.warn(msg % os.path.basename(filename))
