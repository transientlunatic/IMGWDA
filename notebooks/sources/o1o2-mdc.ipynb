# %%
import astropy
from astropy.io import ascii

import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as sstats
import thesis

from matplotlib import rc

# %%
o2_best =np.array([
[0 ,0.0],
[0, 0.0],
[70, 2.49932177721e-09],
[70, np.nan],
[153, 8.40433779172e-10],
[235, 1.41956416652e-09],
[554, 1.4670198181e-08],
[849, 6.12504530029e-08],
[1304, 2.83207779366e-07],
[1615, 6.03402168113e-07],
[2000, 2.38696287165e-06],
[2477, 7.33176393337e-06],
[3067, 1.88020391971e-05],
[150, 9.36855310074e-10],
[300, 3.7474212403e-09],
[750, 3.8716979651e-08]]
)

# %%
o1_best = np.array([
[70.0, 5.9483720834e-08],
[153.0 ,1.27743801866e-09],
[235.0, 4.06614962009e-09],
[554.0, 4.31196162678e-08],
[849.0, 1.6193161442e-07],
[150.0, 1.92646716262e-09],
[300.0 ,9.26040093715e-09],
[1615.0, 1.67710587665e-06],
[2000.0, 6.47498642411e-06],
[2477.0, 1.58120856317e-05],
[3067.0, 4.53285445865e-05]])

# %%
height = 3
width = height * 1.618

figsize = (width, height)

colors = {"bayeswave": "#7469AF",
          "cwb": "#740B0F",
          "lib": "#809FFF"}

def lighten(color, amount=0.5):
    """
    Lightens the given color by multiplying (1-luminosity) by the given amount.
    Input can be matplotlib color string, hex string, or RGB tuple.

    See
    https://gist.github.com/ihincks/6a420b599f43fcd7dbd79d56798c4e5a

    Examples:
    >> lighten_color('g', 0.3)
    >> lighten_color('#F034A3', 0.6)
    >> lighten_color((.3,.55,.1), 0.5)
    """
    import matplotlib.colors as mc
    import colorsys
    try:
        c = mc.cnames[color]
    except:
        c = color
    c = colorsys.rgb_to_hls(*mc.to_rgb(c))
    return colorsys.hls_to_rgb(c[0], 1 - amount * (1 - c[1]), c[2])

# %%
f, ax = plt.subplots(1,1, dpi=300)

ax.scatter(o1_best[:,0], o1_best[:,1], label='O1')
ax.scatter(o2_best[:,0],o2_best[:,1], marker='^',label='O2')

ax.set_yscale('log')
ax.set_xscale('log')
ax.set_xlim(50,10e3)
ax.set_ylim(1e-10,1e-4)
ax.grid(which='both',alpha=0.2)
ax.set_xlabel("Frequency (Hz)")
ax.set_ylabel("Energy ($M_\odot c^2$)")
ax.legend(loc=2)

f.tight_layout()

f = thesis.thesisify(f)

f.savefig("../../figures/sources/o1o2-sensitivity.pdf")

# %%
io
